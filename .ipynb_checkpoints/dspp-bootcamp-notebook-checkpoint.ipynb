# %% [markdown]
# # DSPP Bootcamp Material
#
# ## Purpose
# Provide support for Data Camp module and answer questions, data wrangling practice, data visualization in matplotlib, plotnine, and seaborn to complement Johnson’s plotnine lectures
#
# ## Bootcamp Instructors
# Gloria Li
#
# Vince Egalla

# %% [markdown]
# ## Style Guide Resources
# ### Python: PEP 8
# https://peps.python.org/pep-0008/
#
# This document gives coding conventions for the Python code comprising the standard library in the main Python distribution. Please see the companion informational PEP describing style guidelines for the C code in the C implementation of Python.
#
# ### R: Tidyverse Style Guide for use in Stats I or with PlotNine Data Visualization
# http://adv-r.had.co.nz/Style.html
#
# The following guide describes the style that [Hadley Wickam] uses. It is based on Google’s R style guide, with a few tweaks.

# %% [markdown]
# ## Important Cheat Sheets
# ### Pandas Cheat Sheet
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
#
# ### Pandas Cheat Sheet by DataCamp
# http://datacamp-community-prod.s3.amazonaws.com/f04456d7-8e61-482f-9cc9-da6f7f25fc9b
#
# ### Git Cheat Sheet
# https://education.github.com/git-cheat-sheet-education.pdf
#
# ### Markdown Cheat Sheet
# https://www.markdownguide.org/cheat-sheet/

# %% [markdown]
# ## Resources From Gloria and Vince's Data Science I Course (Fall 2020)
#
# Data wrangling: http://ericdunford.com/ppol564/lectures/week_06/week-06-async-material.html
#
# Data viz: http://ericdunford.com/ppol564/lectures/week_07/week-07-async-material.html

# %% [markdown]
# ![81E29540-F9B1-4B70-AC7B-ECB5658C725F.png](attachment:81E29540-F9B1-4B70-AC7B-ECB5658C725F.png)

# %%
## Install gapminder package for data
# !pip install gapminder
# Out:
# Requirement already satisfied: gapminder in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (0.1)
# Requirement already satisfied: pandas in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from gapminder) (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from pandas->gapminder) (2022.2.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from pandas->gapminder) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from pandas->gapminder) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from python-dateutil>=2.8.1->pandas->gapminder) (1.16.0)

# %%
## Load packages
import pandas as pd
import numpy as np

# %%
## Read in data 
from gapminder import gapminder

## If reading gapminder locally
# gapminder = pd.read_csv("gapminder.csv")

# %%
## First five observations
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
## Gapminder dimensions
gapminder.shape
# Out:
# (1704, 6)

# %%
## Gapminder information
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ## Data Cleaning/Interpretation

# %% [markdown]
# #### 1. How many countries & continents are in the data?

# %%
## Built-in function 
gapminder[['country','continent']].nunique()
# Out:
# country      142
# continent      5
# dtype: int64

# %%
## Column-wise apply to find unique
country_unique = gapminder[['country','continent']].apply(lambda x: len(x.unique()), axis = 0)

# %%
gapminder[['country','continent']].apply(lambda x: len(x.unique()), axis = 0)
# Out:
# country      142
# continent      5
# dtype: int64

# %% [markdown]
# #### Response to student question of a row-wise filter and then a column-wise column select

# %%
## Use of loc + nunique()
gapminder.loc[gapminder['continent'] == "Europe", ['country','continent']].nunique()
# Out:
# country      30
# continent     1
# dtype: int64

# %%
## Use of filter >> query >> apply functions
gapminder.filter(items=['country','continent','year'])\
    .query("continent == 'Europe'")\
    .apply(lambda x: len(x.unique()), axis = 0)
# Out:
# country      30
# continent     1
# year         12
# dtype: int64

# %%
## Built-in function, then attribute (size) of result
print(gapminder['country'].drop_duplicates().size)

print(gapminder['continent'].drop_duplicates().size)
# Out:
# 142
# 5

# %%
## ... Or using shape
print(gapminder['country'].drop_duplicates().shape[0])

print(gapminder['continent'].drop_duplicates().shape[0])
# Out:
# 142
# 5

# %% [markdown]
# #### 4. From a (simulated) imperfect data set, which countries are missing years of data?

# %%
## Randomly drop 200 observations from Gapminder to produce imperfect dat
import numpy as np
np.random.seed(564)

remove_n = 200
drop_indices = np.random.choice(gapminder.index, remove_n, replace=False)
gm_subset = gapminder.drop(drop_indices)

print(f"Gapminder data set is originally {gapminder.shape[0]} observations.")
print(f"Gapminder data subset is now {gm_subset.shape[0]} observations.")
# Out:
# Gapminder data set is originally 1704 observations.
# Gapminder data subset is now 1504 observations.

# %%
## Count how many unique year values exist per country within Gapminder subset with missing data
gm_subset.groupby(['country'])\
    .agg({'year':'nunique'})\
    .reset_index()\
    .sort_values(by='year', ascending=True)\
    .head(10)
# Out:
#          country  year
# 118        Spain     7
# 65       Jamaica     8
# 130      Tunisia     8
# 128         Togo     8
# 0    Afghanistan     9
# 66         Japan     9
# 100         Peru     9
# 35      Djibouti     9
# 64         Italy     9
# 62       Ireland     9

# %% [markdown]
# #### Which year is missing the most amount of data?

# %%
gm_subset[['year']].value_counts().sort_index()
# Out:
# year
# 1952    116
# 1957    124
# 1962    129
# 1967    126
# 1972    130
# 1977    125
# 1982    132
# 1987    121
# 1992    127
# 1997    120
# 2002    126
# 2007    128
# dtype: int64

# %% [markdown]
# #### 3. Which country has the lowest average population (across years) in the data?

# %%
gapminder.groupby(['country'])['pop']\
    .mean()\
    .reset_index()\
    .sort_values(by="pop")\
    .head(1)
# Out:
#                    country            pop
# 108  Sao Tome and Principe  105977.833333

# %%
## Alternative method: Pandas queries
## https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

gapminder.groupby(['country'])['pop']\
    .mean()\
    .reset_index()\
    .query('pop == pop.min()')
# Out:
#                    country            pop
# 108  Sao Tome and Principe  105977.833333

# %% [markdown]
# #### 4. What is the average life expectancy in Europe?

# %%
gapminder.groupby(["continent"])\
    .agg({'lifeExp':'mean'})\
    .reset_index()
# Out:
#   continent    lifeExp
# 0    Africa  48.865330
# 1  Americas  64.658737
# 2      Asia  60.064903
# 3    Europe  71.903686
# 4   Oceania  74.326208

# %% [markdown]
# #### 5. Can you describe the descriptive statistics of the numerical variables?

# %%
gapminder.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165876
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
## Highlight f-strings here
## https://realpython.com/python-f-strings/
## https://peps.python.org/pep-0498/

## Alternative to printing strings with concatenations
# print("This string with the following "+ str(variable) + " followed by more strings.")

print(f"The minimum year is {gapminder.describe()['year'].loc['min']}.")
print(f"The median life expectancy is {gapminder.describe()['lifeExp'].loc['50%']}.")
print(f"The mean population is {gapminder.describe()['pop'].loc['mean']}.")
print(f"The max GDP per Capita is {gapminder.describe()['gdpPercap'].loc['max']}.")
# Out:
# The minimum year is 1952.0.
# The median life expectancy is 60.7125.
# The mean population is 29601212.324530516.
# The max GDP per Capita is 113523.1329.

# %%
## Assigning the value to a variable to insert into the f-string
gm_min = gapminder.describe()['year'].loc['min']
gm_med = gapminder.describe()['lifeExp'].loc['50%']
gm_mean = gapminder.describe()['pop'].loc['mean']
gm_max = gapminder.describe()['gdpPercap'].loc['max']

print(f"The minimum year is {gm_min}.")
print(f"The median life expectancy is {gm_med}.")
print(f"The mean population is {gm_mean}.")
print(f"The max GDP per Capita is {gm_max}.")
# Out:
# The minimum year is 1952.0.
# The median life expectancy is 60.7125.
# The mean population is 29601212.324530516.
# The max GDP per Capita is 113523.1329.

# %% [markdown]
# #### 5. You were asked to take a random sample of 10 rows from the dataset. How do you do this?

# %%
gapminder.sample(n=10, random_state = 564)
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 874      Lebanon      Asia  2002   71.028   3677780   9313.938830
# 1570     Tunisia    Africa  2002   73.042   9770575   5722.895655
# 586        Ghana    Africa  2002   58.453  20550751   1111.984578
# 1521    Tanzania    Africa  1997   48.466  30686889    789.186223
# 913   Madagascar    Africa  1957   38.865   5181679   1589.202750
# 1574      Turkey    Europe  1962   52.098  29788695   2322.869908
# 737         Iraq      Asia  1977   60.413  11882916  14688.235070
# 686      Iceland    Europe  1962   73.680    182053  10350.159060
# 1142      Norway    Europe  1962   73.470   3638919  13450.401510
# 1336      Serbia    Europe  1972   68.700   8313288  10522.067490

# %% [markdown]
# #### Can we adjust names to common country names?

# %%
gapminder[gapminder['country'].str.contains("Rep\.")]['country'].unique()
# Out:
# array(['Congo, Dem. Rep.', 'Congo, Rep.', 'Korea, Dem. Rep.',
#        'Korea, Rep.', 'Yemen, Rep.'], dtype=object)

# %%
## create conditions
name_cond = [
    gapminder['country'].str.contains("Congo, Rep."),
    gapminder['country'].str.contains("Congo, Dem. Rep."),
    gapminder['country'].str.contains("Korea, Dem. Rep."),
    gapminder['country'].str.contains("Korea, Rep."),
    gapminder['country'].str.contains("Yemen, Rep.")
]

code_to = [
    "Republic of Congo", 
    "Democratic Republic of Congo",
    "North Korea",
    "South Korea",
    "Republic of Yemen"
]

gapminder['updated_country'] = np.select(
    name_cond,
    code_to, 
    default=gapminder['country']
)

# %%
gapminder[gapminder['updated_country'].isin(code_to)]['updated_country'].unique()
# Out:
# array(['Democratic Republic of Congo', 'Republic of Congo', 'North Korea',
#        'South Korea', 'Republic of Yemen'], dtype=object)

# %% [markdown]
# ## Data Visualization with Gapminder

# %%
## Visualization data set
data_viz = gapminder.groupby(['continent','year'])\
    .agg({'lifeExp':'mean'})\
    .reset_index()

# %%
## Visualization with plotnine
import plotnine
from plotnine import *

(
    ggplot(
        data_viz, 
        aes(
            x='year', 
            y='lifeExp', 
            group='continent', 
            color='continent')) +
    geom_line() +
    labs(color = "Country") +
    xlab("Year") +
    ylab("Life Expectancy") +
    ggtitle("Average Life Expectancy over Time,\nby Continent") +
    scale_x_continuous(breaks=range(1952, 2007+1, 5)) +
    theme_bw()
)
# Out:
# <ggplot: (140455185529)>

# %%
## Visualization with Matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8)) 

# lines
for i in data_viz['continent'].unique():
    plt.plot('year', 'lifeExp', data=data_viz[data_viz['continent'] == i], label=i)

# x-axis 
plt.xticks(range(1952, 2007+1, 5))    

# show legend
plt.legend()

# labels
plt.xlabel("Years")
plt.ylabel("Life Expectancy")
plt.title("Average Life Expectancy over Time,\nby Continent")

plt.show()

# %% [markdown]
# ## Data Visualization

# %%
# !pip install missingno plotnine seaborn palmerpenguins
# Out:
# Requirement already satisfied: missingno in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (0.5.1)
# Requirement already satisfied: plotnine in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (0.9.0)
# Requirement already satisfied: seaborn in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (0.12.0)
# Requirement already satisfied: palmerpenguins in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (0.1.4)
# Requirement already satisfied: numpy in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from missingno) (1.23.2)
# Requirement already satisfied: scipy in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from missingno) (1.9.1)
# Requirement already satisfied: matplotlib in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from missingno) (3.5.3)
# Requirement already satisfied: mizani>=0.7.3 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from plotnine) (0.7.4)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from plotnine) (0.13.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from plotnine) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from matplotlib->missingno) (4.37.1)
# Requirement already satisfied: palettable in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from mizani>=0.7.3->plotnine) (3.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from pandas>=1.3.5->plotnine) (2022.2.1)
# Requirement already satisfied: six in c:\users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages (from patsy>=0.5.1->plotnine) (1.16.0)

# %%
import missingno as msno

from plotnine import *
import seaborn as sns
import matplotlib.pyplot as plt

from palmerpenguins import load_penguins

# %%
penguins = load_penguins()
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
msno.matrix(penguins)
# Out:
# <AxesSubplot:>

# %%
msno.bar(penguins)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Plot the body mass in grams (body_mass_g) as a boxplot. Make sure the following is true:
#
# - body_mass_g is on the x-axis with a label that reads “Body Mass (Grams)”; and the y-axis is species and has no label.
# - Add a title that reads “Penguin Body Mass”
# - Each boxplot should be a different fill for each species but make sure there is no legend.

# %% [markdown]
# #### Plotnine solution

# %%
p = \
(
ggplot(penguins,aes(x="species",y="body_mass_g",fill='species')) +
geom_boxplot(alpha=.6,show_legend=False) + # added some additional transparency
coord_flip() +
labs(x="", y = "Body Mass (Grams)",title="Penguin Body Mass")
)

p
# Out:
# C:\Users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages\plotnine\layer.py:334: PlotnineWarning: stat_boxplot : Removed 2 rows containing non-finite values.
# <ggplot: (140457145332)>

# %%
# show + theme_538, theme_xkcd, theme_void, theme_matplotlib

# %% [markdown]
# #### Seaborn solution

# %%
sns.boxplot(x="body_mass_g",y="species",data=penguins)
plt.xlabel("Body Mass (Grams)")
plt.ylabel("")
plt.title("Penguin Body Mass")
plt.show()

# %%
# You can also set titles using the seaborn object directly
ax = sns.boxplot(x="body_mass_g",y="species",data=penguins)
ax.set_title("Penguin Body Mass")
ax.set_ylabel("")
ax.set_xlabel("Body Mass (Grams)")
# Out:
# Text(0.5, 0, 'Body Mass (Grams)')

# %% [markdown]
# Using plotnine, generate a scatter plot where flipper length (flipper_length_mm) is on the x-axis and bill length (bill_length_mm) is on the y-axis. The points should be a different color given the species of the penguin. Also, the points should be sized differently given the body mass (body_mass_g) of the penguin.
#
# In addition to the above:
#
# points should be transparent (alpha=.5)
# Labs should read: x-axis = “Flipper Length (MM)”, y-axis = “Bill Length (MM)”, color legend = “Penguin Species” and size legend = “Body Mass (Grams)”
# The plot theme should be minimal.

# %%
(
    ggplot(penguins,aes(x="flipper_length_mm",
                   y="bill_length_mm",
                   color="species",
                   size="body_mass_g")) +
    geom_point(alpha=.5) +
    labs(x = "Flipper Length (MM)",y="Bill Length (MM)",
         color="Penguin Species",size = "Body Mass (Grams)") +
    theme_minimal() 
)
# Out:
# C:\Users\vince\anaconda3\envs\dspp-bootcamp\lib\site-packages\plotnine\layer.py:412: PlotnineWarning: geom_point : Removed 2 rows containing missing values.
# <ggplot: (140457357009)>

# %% [markdown]
# Using plotnine, generate barplot that contains the Penguin species on the x-axis and a count of the number of observations for each category on the y-axis. You’ll need to drop all missing observations first.

# %%
penguins.dropna()
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 4         3450.0  female  2007
# 5         3650.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [333 rows x 8 columns]

# %% [markdown]
# From there, do the following:
#
# - Use the fill to break up each species by sex so that two bar plots are side-by-side (hint: position = "dodge").
# - Alter the order so that the “Adelie” species is first, the “Gentoo” second, and the “Chinstrap” third.
# - Change the fill colors so that “female” is “darkorange” and “male” is “black”
# - x-axis label should read “Penguin Species”; the y-axis “Number of Observations”, and the legend should have no title.
# - Add a title that reads “Distribution of Sex by Species”.
# - The theme should be black and white (_bw).

# %%
(
    ggplot(penguins.dropna(),aes(x="species",fill="sex")) +
    geom_bar(position="dodge") +
    scale_x_discrete(limits = ["Adelie","Gentoo","Chinstrap"]) +
    scale_fill_manual(values=["darkorange","black"]) +
    labs(x="Penguin Species",y="Number of Observations", fill="",
         title = "Distribution of Sex by Species") +
    theme_bw()
)
# Out:
# <ggplot: (140457405050)>
